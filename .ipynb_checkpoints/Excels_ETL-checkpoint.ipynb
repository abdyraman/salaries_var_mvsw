# %%
import pandas as pd

# %%
document_1 = 'Resources/17cbf81a-f78e-4c39-ba72-cbd1357ca59e.xlsx'
entities_heads = pd.read_excel(document_1)
entities_heads
# Out:
#    Жынысы жана аймагы боюнча чарбалык субъекттердин жетекчилери  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...

# %%
document_2 = 'Resources/1b008eb4-44f1-4e98-8947-95e7aa47228c.xlsx'
document_2 = pd.read_excel(document_2)
document_2
# Out:
#    Жынысы жана аймагы боюнча жеке менчиктеги чарбалык субъекттердин жетекчилери  \
# 0                       (жылдын башына карата,  адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...

# %%
document_3 = 'Resources/21019f5b-7d23-4e8f-9a86-6c8051d9365f.xlsx'
document_3 = pd.read_excel(document_3)
document_3
# Out:
#    Жынысы жана аймагы боюнча чакан бизнестин жетекчилери  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...

# %%
document_4 = 'Resources/47063a1e-333b-431e-b174-19057f20c671.xlsx'
document_4 = pd.read_excel(document_4)
document_4
# Out:
#           Орточо айлык эмгек акы Среднемесячная заработная плата  \
# 0                            NaN                             NaN
# 1                          (сом)                         (сомов)
# 2                            NaN                             NaN
# 3     Көрсөткүчтөрдүн аталыштары        Наименование показателей
# 4                            NaN                             NaN
# 5            Кыргыз Республикасы           Кыргызская Республика
# 6                            NaN                             NaN
# 7                  Баткен облусу              Баткенская область
# 8              Жалал-Абад облусу         Джалал-Абадская область
# 9                Ысык-Көл облусу          Иссык-Кульская область
# 10                  Нарын облусу               Нарынская область
# 11                     Ош облусу                  Ошская область
# 12                  Талас облусу               Таласская область
# ...

# %%
document_5 = 'Resources/47f5150b-4c3f-46f1-a97e-f5de41eb8cfd.xlsx'
document_5 = pd.read_excel(document_5)
document_5
# Out:
#    Жынысы жана аймагы боюнча менчигинин муниципалдык түрүндөгү чарба жүргүзүүчү субъекттердин жетекчилери  \
# 0                       (жылдын башына карата,  адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# ...

# %%
document_5 = 'Resources/5fd71c91-4975-4710-b2dc-afa6b04e9438.xlsx'
document_5 = pd.read_excel(document_5)
document_5
# Out:
#    Жынысы жана аймагы боюнча ири ишканалардын жетекчилери  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...

# %%
document_6 = 'Resources/6503c27a-6a8b-4a6f-b801-e50122818a15.xlsx'
document_6 = pd.read_excel(document_6)
document_6
# Out:
#    Жынысы жана территориясы боюнча дыйкан чарбаларынын жетекчилери  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...

# %%
document_7 = 'Resources/78867e76a-4ce8-4c20-be65-115838f34e8f.xlsx'
document_7 = pd.read_excel(document_7)
document_7
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/xq/xdbqztz92zs24q39hvzwj65m0000gn/T/ipykernel_3207/3897646954.py in <module>
#       1 document_7 = 'Resources/78867e76a-4ce8-4c20-be65-115838f34e8f.xlsx'
# ----> 2 document_7 = pd.read_excel(document_7)
#       3 document_7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
document_8 = 'Resources/9e687117-2ca4-40a6-93a7-3cc03e436553.xlsx'
document_8 = pd.read_excel(document_8)
document_8
# Out:
#               Жынысы жана аймагы боюнча жеке ишкерлер  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...

# %%
document_9 = 'Resources/adb00f07-5775-4c85-8f55-428f66723a3b.xlsx'
document_9 = pd.read_excel(document_9)
document_9
# Out:
#    Жынысы жана экономикалык иштин түрлөрү боюнча иштеп жаткан чарбалык субъекттердин жетекчилери 1  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# ..                                                ...
# 88            Экстерриториялык уюмдардын ишмердүүлүгү
# 89                                            Бардыгы
# 90                                             аялдар
# 91                                           эркектер
# 92  1 Экономикалык ишмердиктин мамлекеттик классиф...
#
#    Руководители действующих хозяйствующих субъектов по полу и видам экономической деятельности 1  \
# 0                           (на начало года, человек)
# 1                                                 NaN
# 2                                                 NaN
# ...

# %%
document_10 = 'Resources/c8316b4d-bb98-4c01-a7ff-efacf7ba78b9.xlsx'
document_10 = pd.read_excel(document_10)
document_10
# Out:
#    Эркектердин эмгек акысына  карата аялдардын эмгек акысынын   аймактар боюнча  катышы  \
# 0                                       (пайыз менен)
# 1                                                 NaN
# 2                             Көрсөткүчтөрдүн аталышы
# 3                                 Кыргыз Республикасы
# 4                                       Баткен облусу
# 5                                   Жалал-Абад облусу
# 6                                     Ысык-Көл облусу
# 7                                        Нарын облусу
# 8                                           Ош облусу
# 9                                        Талас облусу
# 10                                         Чүй облусу
# 11                                          Бишкек ш.
# 12                                              Ош ш.
# 13  Булак: Ноябрда  өткөрүлө турган ишканалардын ж...
#
#    Отношение заработной платы  женщин к заработной плате  мужчин по территории  \
# ...

# %%
document_11 = 'Resources/d76484df-fbee-4045-be02-abaf90b78677.xlsx'
document_11 = pd.read_excel(document_11)
document_11
# Out:
#    Жынысы жана аймагы боюнча мамлекеттик менчиктеги чарбалык субъекттердин жетекчилери  \
# 0                        (жылдын башына карата, адам)
# 1                                                 NaN
# 2                                                 NaN
# 3                                 Кыргыз Республикасы
# 4                                             Бардыгы
# 5                                              аялдар
# 6                                            эркектер
# 7                                                 NaN
# 8                                       Баткен облусу
# 9                                             Бардыгы
# 10                                             аялдар
# 11                                           эркектер
# 12                                  Жалал-Абад облусу
# 13                                            Бардыгы
# 14                                             аялдар
# 15                                           эркектер
# ...
